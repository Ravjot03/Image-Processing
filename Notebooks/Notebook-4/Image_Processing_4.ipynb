# %% [markdown]
# # **Image Processing in OpenCV**

# %% [markdown]
# **Ravjot Singh**
#
# E-mail: ravjot313@gmail.com
#
# M: +91-9654446404
#
# LinkedIn: https://www.linkedin.com/in/ravjot-singh-1a0777149/
#
# Github: https://github.com/Ravjot03

# %% [markdown]
# #Image Gradients

# %% [markdown]
# Importing the libraries

# %%
import cv2
import matplotlib.pyplot as plt
import numpy

# %% [markdown]
# Reading an image of Sudoku game using OpenCV and Matpltlotlib libraries

# %%
img = cv2.imread('sudoku.jpg')
plt.imshow(img)

# %% [markdown]
# #Sobel Derivative

# %%
sobel_x = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=1)

plt.subplot(1,2,1),plt.imshow(img,cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(1,2,2),plt.imshow(sobel_x,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (Text(0.5, 1.0, 'Sobel X'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %%
sobel_y = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=1)

plt.subplot(1,2,1),plt.imshow(img,cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(1,2,2),plt.imshow(sobel_y,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (Text(0.5, 1.0, 'Sobel Y'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %% [markdown]
# #Laplacian Derivative

# %%
laplace = cv2.Laplacian(img,cv2.CV_64F,ksize=5)

plt.subplot(121), plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(122), plt.imshow(laplace)
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (Text(0.5, 1.0, 'Laplacian'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))
